# %%
from pyspark.sql import SparkSession
from pyspark.ml.linalg import Vectors, VectorUDT
from pyspark.sql.functions import collect_list, udf, col, max, size
from pyspark.ml.feature import CountVectorizer, MinHashLSH

# %%
def main(spark):

    '''1. Preprocessing Data '''
    # Load the ratings.csv into DataFrame
    ratings_df = spark.read.csv(f'/home/hl5679/capstone-project-cap-19/ml-latest/ratings.csv', schema='userId INT, movieId STRING, rating FLOAT, timestamp BIGINT')

#     ratings_df.cache() #Cache for optimizing
    
    # Group by userId and collect all movieIds into a list
    ratings_df_grouped = ratings_df.groupBy("userId").agg(collect_list("movieId").alias("movieIds")).cache()
    # ratings_df_grouped = ratings_df_grouped.repartition("userId")
#     ratings_df_grouped.cache() #Cache for optimizing
#     ratings_df_grouped.show()
    
    ratings_df_filtered = ratings_df_grouped.filter(size("movieIds") >= 5)
    
    # Vectorize moviIds
    cv = CountVectorizer(inputCol = 'movieIds', outputCol = 'features')
    model = cv.fit(ratings_df_grouped)
    ratings_df_final = model.transform(ratings_df_filtered)
    # ratings_df_final.show()
    

    ''' 2. Applying MinHash '''
    mh = MinHashLSH(inputCol="features", outputCol="hashes", numHashTables=5)
    model = mh.fit(ratings_df_final)

    print("Transformed Data\n")
    transformed_df = model.transform(ratings_df_final)
    similar_pairs = model.approxSimilarityJoin(transformed_df, transformed_df, 0.6, distCol="JaccardDistance")
    # similar_pairs = similar_pairs.filter("datasetA.userId < datasetB.userId")
#     similar_pairs.show()
    

    print("100 similarity pairs\n")
    similar_pairs = similar_pairs.filter("datasetA.userId < datasetB.userId").orderBy("JaccardDistance", ascending=True).limit(100)
    # top_100_pairs.select("datasetA.userId", "datasetB.userId", "JaccardDistance").show(100)
    # top_100_pairs.printSchema()

    print("Simplified df\n")
    simplified_df = similar_pairs.select(
        col("datasetA.userId").alias("userIdA"),
        col("datasetB.userId").alias("userIdB"),
        "JaccardDistance"
    )

    print("Write simplified df to Parquet\n")
    # Write the simplified DataFrame to parquet
    simplified_df.write.parquet('top100pairs_all')

# %%
# Only enter this block if we're in main
if __name__ == "__main__":

    # Create the spark session object
#     spark = SparkSession.builder.appName('minHash').getOrCreate()
    
#     spark = SparkSession.builder \
#     .appName("Spark Application") \
#     .config("spark.executor.memory", "16g") \
#     .config("spark.driver.memory", "16g") \
#     .config("spark.serializer", "org.apache.spark.serializer.KryoSerializer") \
#     .config("spark.driver.extraJavaOptions", "-XX:+UseG1GC") \
#     .config("spark.executor.extraJavaOptions", "-XX:+UseG1GC") \
#     .getOrCreate()

    spark = SparkSession.builder \
                        .appName('minHash') \
                        .getOrCreate()

    # Call our main routine
    main(spark)
# Out:
# 24/05/10 17:17:47 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_163 in memory.
# 24/05/10 17:17:47 WARN MemoryStore: Not enough space to cache rdd_7_163 in memory! (computed 384.0 B so far)
# 24/05/10 17:17:47 WARN BlockManager: Persisting block rdd_7_163 to disk instead.
# 24/05/10 17:17:47 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_165 in memory.
# 24/05/10 17:17:47 WARN MemoryStore: Not enough space to cache rdd_7_165 in memory! (computed 384.0 B so far)
# 24/05/10 17:17:47 WARN BlockManager: Persisting block rdd_7_165 to disk instead.
# 24/05/10 17:17:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_167 in memory.
# 24/05/10 17:17:48 WARN MemoryStore: Not enough space to cache rdd_7_167 in memory! (computed 384.0 B so far)
# 24/05/10 17:17:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_168 in memory.
# 24/05/10 17:17:48 WARN MemoryStore: Not enough space to cache rdd_7_168 in memory! (computed 384.0 B so far)
# 24/05/10 17:17:48 WARN BlockManager: Persisting block rdd_7_168 to disk instead.
# 24/05/10 17:17:48 WARN BlockManager: Persisting block rdd_7_167 to disk instead.
# 24/05/10 17:17:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_169 in memory.
# 24/05/10 17:17:48 WARN MemoryStore: Not enough space to cache rdd_7_169 in memory! (computed 384.0 B so far)
# 24/05/10 17:17:48 WARN BlockManager: Persisting block rdd_7_169 to disk instead.
# 24/05/10 17:17:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_170 in memory.
# 24/05/10 17:17:48 WARN MemoryStore: Not enough space to cache rdd_7_170 in memory! (computed 384.0 B so far)
# 24/05/10 17:17:48 WARN BlockManager: Persisting block rdd_7_170 to disk instead.
# 24/05/10 17:17:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_172 in memory.
# 24/05/10 17:17:48 WARN MemoryStore: Not enough space to cache rdd_7_172 in memory! (computed 384.0 B so far)
# 24/05/10 17:17:48 WARN BlockManager: Persisting block rdd_7_172 to disk instead.
# 24/05/10 17:17:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_176 in memory.
# 24/05/10 17:17:48 WARN MemoryStore: Not enough space to cache rdd_7_176 in memory! (computed 384.0 B so far)
# 24/05/10 17:17:48 WARN BlockManager: Persisting block rdd_7_176 to disk instead.
# 24/05/10 17:17:48 WARN MemoryStore: Not enough space to cache rdd_7_177 in memory! (computed 2.6 MiB so far)
# 24/05/10 17:17:48 WARN BlockManager: Persisting block rdd_7_177 to disk instead.
# 24/05/10 17:17:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_180 in memory.
# 24/05/10 17:17:49 WARN MemoryStore: Not enough space to cache rdd_7_180 in memory! (computed 384.0 B so far)
# 24/05/10 17:17:49 WARN BlockManager: Persisting block rdd_7_180 to disk instead.
# 24/05/10 17:17:49 WARN MemoryStore: Not enough space to cache rdd_7_184 in memory! (computed 2.9 MiB so far)
# 24/05/10 17:17:49 WARN BlockManager: Persisting block rdd_7_184 to disk instead.
# 24/05/10 17:17:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_196 in memory.
# 24/05/10 17:17:50 WARN MemoryStore: Not enough space to cache rdd_7_196 in memory! (computed 384.0 B so far)
# 24/05/10 17:17:50 WARN BlockManager: Persisting block rdd_7_196 to disk instead.
# Transformed Data
#
# 100 similarity pairs
#
# Simplified df
#
# Write simplified df to Parquet
# 24/05/10 17:18:00 WARN MemoryStore: Not enough space to cache rdd_7_10 in memory! (computed 2.7 MiB so far)
# 24/05/10 17:18:00 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_11 in memory.
# 24/05/10 17:18:00 WARN MemoryStore: Not enough space to cache rdd_7_11 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:00 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_12 in memory.
# 24/05/10 17:18:00 WARN MemoryStore: Not enough space to cache rdd_7_12 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:01 WARN MemoryStore: Not enough space to cache rdd_7_13 in memory! (computed 2.5 MiB so far)
# 24/05/10 17:18:01 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_14 in memory.
# 24/05/10 17:18:01 WARN MemoryStore: Not enough space to cache rdd_7_14 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:01 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_15 in memory.
# 24/05/10 17:18:01 WARN MemoryStore: Not enough space to cache rdd_7_15 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:02 WARN MemoryStore: Not enough space to cache rdd_7_16 in memory! (computed 2.5 MiB so far)
# 24/05/10 17:18:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_17 in memory.
# 24/05/10 17:18:02 WARN MemoryStore: Not enough space to cache rdd_7_17 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_18 in memory.
# 24/05/10 17:18:02 WARN MemoryStore: Not enough space to cache rdd_7_18 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_19 in memory.
# 24/05/10 17:18:02 WARN MemoryStore: Not enough space to cache rdd_7_19 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:03 WARN MemoryStore: Not enough space to cache rdd_7_20 in memory! (computed 2.6 MiB so far)
# 24/05/10 17:18:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_21 in memory.
# 24/05/10 17:18:03 WARN MemoryStore: Not enough space to cache rdd_7_21 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_22 in memory.
# 24/05/10 17:18:03 WARN MemoryStore: Not enough space to cache rdd_7_22 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_23 in memory.
# 24/05/10 17:18:03 WARN MemoryStore: Not enough space to cache rdd_7_23 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:04 WARN MemoryStore: Not enough space to cache rdd_7_24 in memory! (computed 2.8 MiB so far)
# 24/05/10 17:18:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_25 in memory.
# 24/05/10 17:18:04 WARN MemoryStore: Not enough space to cache rdd_7_25 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_26 in memory.
# 24/05/10 17:18:04 WARN MemoryStore: Not enough space to cache rdd_7_26 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:04 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_27 in memory.
# 24/05/10 17:18:04 WARN MemoryStore: Not enough space to cache rdd_7_27 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:05 WARN MemoryStore: Not enough space to cache rdd_7_29 in memory! (computed 2.5 MiB so far)
# 24/05/10 17:18:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_28 in memory.
# 24/05/10 17:18:05 WARN MemoryStore: Not enough space to cache rdd_7_28 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:05 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_30 in memory.
# 24/05/10 17:18:05 WARN MemoryStore: Not enough space to cache rdd_7_30 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:06 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_31 in memory.
# 24/05/10 17:18:06 WARN MemoryStore: Not enough space to cache rdd_7_31 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:06 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_32 in memory.
# 24/05/10 17:18:06 WARN MemoryStore: Not enough space to cache rdd_7_32 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:07 WARN MemoryStore: Not enough space to cache rdd_7_33 in memory! (computed 2.4 MiB so far)
# 24/05/10 17:18:07 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_34 in memory.
# 24/05/10 17:18:07 WARN MemoryStore: Not enough space to cache rdd_7_34 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:07 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_35 in memory.
# 24/05/10 17:18:07 WARN MemoryStore: Not enough space to cache rdd_7_35 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:08 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_36 in memory.
# 24/05/10 17:18:08 WARN MemoryStore: Not enough space to cache rdd_7_36 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:08 WARN MemoryStore: Not enough space to cache rdd_7_38 in memory! (computed 2.6 MiB so far)
# 24/05/10 17:18:08 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_37 in memory.
# 24/05/10 17:18:08 WARN MemoryStore: Not enough space to cache rdd_7_37 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:08 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_39 in memory.
# 24/05/10 17:18:08 WARN MemoryStore: Not enough space to cache rdd_7_39 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_40 in memory.
# 24/05/10 17:18:09 WARN MemoryStore: Not enough space to cache rdd_7_40 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:09 WARN MemoryStore: Not enough space to cache rdd_7_41 in memory! (computed 2.7 MiB so far)
# 24/05/10 17:18:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_42 in memory.
# 24/05/10 17:18:09 WARN MemoryStore: Not enough space to cache rdd_7_42 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_43 in memory.
# 24/05/10 17:18:09 WARN MemoryStore: Not enough space to cache rdd_7_43 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_44 in memory.
# 24/05/10 17:18:10 WARN MemoryStore: Not enough space to cache rdd_7_44 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:10 WARN MemoryStore: Not enough space to cache rdd_7_45 in memory! (computed 2.8 MiB so far)
# 24/05/10 17:18:53 WARN MemoryStore: Not enough space to cache rdd_7_10 in memory! (computed 2.7 MiB so far)
# 24/05/10 17:18:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_11 in memory.
# 24/05/10 17:18:54 WARN MemoryStore: Not enough space to cache rdd_7_11 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_12 in memory.
# 24/05/10 17:18:54 WARN MemoryStore: Not enough space to cache rdd_7_12 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_13 in memory.
# 24/05/10 17:18:54 WARN MemoryStore: Not enough space to cache rdd_7_13 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:54 WARN MemoryStore: Not enough space to cache rdd_7_14 in memory! (computed 2.5 MiB so far)
# 24/05/10 17:18:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_15 in memory.
# 24/05/10 17:18:55 WARN MemoryStore: Not enough space to cache rdd_7_15 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_16 in memory.
# 24/05/10 17:18:55 WARN MemoryStore: Not enough space to cache rdd_7_16 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:55 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_17 in memory.
# 24/05/10 17:18:55 WARN MemoryStore: Not enough space to cache rdd_7_17 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:55 WARN MemoryStore: Not enough space to cache rdd_7_18 in memory! (computed 2.9 MiB so far)
# 24/05/10 17:18:56 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_19 in memory.
# 24/05/10 17:18:56 WARN MemoryStore: Not enough space to cache rdd_7_19 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:56 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_20 in memory.
# 24/05/10 17:18:56 WARN MemoryStore: Not enough space to cache rdd_7_20 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:56 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_21 in memory.
# 24/05/10 17:18:56 WARN MemoryStore: Not enough space to cache rdd_7_21 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:57 WARN MemoryStore: Not enough space to cache rdd_7_22 in memory! (computed 2.4 MiB so far)
# 24/05/10 17:18:57 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_23 in memory.
# 24/05/10 17:18:57 WARN MemoryStore: Not enough space to cache rdd_7_23 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:57 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_24 in memory.
# 24/05/10 17:18:57 WARN MemoryStore: Not enough space to cache rdd_7_24 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:57 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_25 in memory.
# 24/05/10 17:18:57 WARN MemoryStore: Not enough space to cache rdd_7_25 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:58 WARN MemoryStore: Not enough space to cache rdd_7_26 in memory! (computed 2.4 MiB so far)
# 24/05/10 17:18:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_27 in memory.
# 24/05/10 17:18:58 WARN MemoryStore: Not enough space to cache rdd_7_27 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_28 in memory.
# 24/05/10 17:18:58 WARN MemoryStore: Not enough space to cache rdd_7_28 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_29 in memory.
# 24/05/10 17:18:58 WARN MemoryStore: Not enough space to cache rdd_7_29 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:59 WARN MemoryStore: Not enough space to cache rdd_7_30 in memory! (computed 2.8 MiB so far)
# 24/05/10 17:18:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_31 in memory.
# 24/05/10 17:18:59 WARN MemoryStore: Not enough space to cache rdd_7_31 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_32 in memory.
# 24/05/10 17:18:59 WARN MemoryStore: Not enough space to cache rdd_7_32 in memory! (computed 384.0 B so far)
# 24/05/10 17:18:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_33 in memory.
# 24/05/10 17:18:59 WARN MemoryStore: Not enough space to cache rdd_7_33 in memory! (computed 384.0 B so far)
# 24/05/10 17:19:00 WARN MemoryStore: Not enough space to cache rdd_7_34 in memory! (computed 2.5 MiB so far)
# 24/05/10 17:19:00 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_35 in memory.
# 24/05/10 17:19:00 WARN MemoryStore: Not enough space to cache rdd_7_35 in memory! (computed 384.0 B so far)
# 24/05/10 17:19:00 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_36 in memory.
# 24/05/10 17:19:00 WARN MemoryStore: Not enough space to cache rdd_7_36 in memory! (computed 384.0 B so far)
# 24/05/10 17:19:01 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_37 in memory.
# 24/05/10 17:19:01 WARN MemoryStore: Not enough space to cache rdd_7_37 in memory! (computed 384.0 B so far)
# 24/05/10 17:19:01 WARN MemoryStore: Not enough space to cache rdd_7_38 in memory! (computed 2.6 MiB so far)
# 24/05/10 17:19:01 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_40 in memory.
# 24/05/10 17:19:01 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_39 in memory.
# 24/05/10 17:19:01 WARN MemoryStore: Not enough space to cache rdd_7_40 in memory! (computed 384.0 B so far)
# 24/05/10 17:19:01 WARN MemoryStore: Not enough space to cache rdd_7_39 in memory! (computed 384.0 B so far)
# 24/05/10 17:19:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_41 in memory.
# 24/05/10 17:19:02 WARN MemoryStore: Not enough space to cache rdd_7_41 in memory! (computed 384.0 B so far)
# 24/05/10 17:19:02 WARN MemoryStore: Not enough space to cache rdd_7_42 in memory! (computed 2.6 MiB so far)
# 24/05/10 17:19:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_43 in memory.
# 24/05/10 17:19:02 WARN MemoryStore: Not enough space to cache rdd_7_43 in memory! (computed 384.0 B so far)
# 24/05/10 17:19:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_44 in memory.
# 24/05/10 17:19:02 WARN MemoryStore: Not enough space to cache rdd_7_44 in memory! (computed 384.0 B so far)
# 24/05/10 17:19:03 WARN MemoryStore: Not enough space to cache rdd_7_45 in memory! (computed 2.8 MiB so far)

# %%
'''
+--------------------+--------------------+------------------+
|            datasetA|            datasetB|   JaccardDistance|
+--------------------+--------------------+------------------+
|{159361, [50, 318...|{6820, [318, 4995...|0.5555555555555556|
|{112094, [1196, 1...|{112094, [1196, 1...|               0.0|
|{254602, [48, 150...|{254602, [48, 150...|               0.0|
|{257335, [260, 31...|{257335, [260, 31...|               0.0|
|{288760, [1, 47, ...|{288760, [1, 47, ...|               0.0|
|{214820, [2028, 2...|{214820, [2028, 2...|               0.0|
|{77749, [223, 296...|{77749, [223, 296...|               0.0|
|{26650, [318, 527...|{85346, [260, 527...|0.5151515151515151|
|{131756, [3578, 3...|{214189, [260, 52...|0.5227272727272727|
|{185669, [318, 35...|{185669, [318, 35...|               0.0|
|{278829, [10, 18,...|{278829, [10, 18,...|               0.0|
|{220550, [260, 29...|{220550, [260, 29...|               0.0|
|{137155, [19, 165...|{137155, [19, 165...|               0.0|
|{93424, [260, 356...|{93424, [260, 356...|               0.0|
|{131505, [260, 29...|{131505, [260, 29...|               0.0|
|{271048, [6, 50, ...|{271048, [6, 50, ...|               0.0|
|{200191, [47, 185...|{200191, [47, 185...|               0.0|
|{10131, [44, 70, ...|{10131, [44, 70, ...|               0.0|
|{276465, [277, 34...|{276465, [277, 34...|               0.0|
|{98347, [2302], (...|{319979, [1639, 2...|               0.5|
+--------------------+--------------------+------------------+
only showing top 20 rows
'''

# %%
from pyspark.sql import SparkSession

# Create a Spark session
spark = SparkSession.builder \
    .appName("Read and Process Parquet Files") \
    .getOrCreate()

# Read Parquet files from a specified path or multiple paths
df = spark.read.parquet("top100pairs_all")


# Order by a specific column and limit to 100 records
result_df = df.orderBy("JaccardDistance", ascending=True).limit(100)

# Show the results
result_df.write.csv('q1_results', header=True)

# Stop the Spark session
spark.stop()
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/ext3/spark-3.1.2-bin-hadoop3.2/jars/spark-unsafe_2.12-3.1.2.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 24/05/10 19:26:45 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
