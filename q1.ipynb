# %%
from pyspark.sql import SparkSession
from pyspark.ml.linalg import Vectors, VectorUDT
from pyspark.sql.functions import collect_list, udf, col, max
from pyspark.ml.feature import CountVectorizer, MinHashLSH

# %%
def main(spark):

    '''1. Preprocessing Data '''
    # Load the ratings.csv into DataFrame
    ratings_df = spark.read.csv(f'/home/hl5679/capstone-project-cap-19/ml-latest/ratings.csv', schema='userId INT, movieId STRING, rating FLOAT, timestamp BIGINT')

#     ratings_df.cache() #Cache for optimizing
    
    # Group by userId and collect all movieIds into a list
    ratings_df_grouped = ratings_df.groupBy("userId").agg(collect_list("movieId").alias("movieIds")).cache()
    # ratings_df_grouped = ratings_df_grouped.repartition("userId")
#     ratings_df_grouped.cache() #Cache for optimizing
#     ratings_df_grouped.show()
    
    # Vectorize moviIds
    cv = CountVectorizer(inputCol = 'movieIds', outputCol = 'features')
    model = cv.fit(ratings_df_grouped)
    ratings_df_final = model.transform(ratings_df_grouped)
    # ratings_df_final.show()
    

    ''' 2. Applying MinHash '''
    mh = MinHashLSH(inputCol="features", outputCol="hashes", numHashTables=5)
    model = mh.fit(ratings_df_final)

    print("Transformed Data\n")
    transformed_df = model.transform(ratings_df_final)
    similar_pairs = model.approxSimilarityJoin(transformed_df, transformed_df, 0.6, distCol="JaccardDistance")
    # similar_pairs = similar_pairs.filter("datasetA.userId < datasetB.userId")
#     similar_pairs.show()
    

    print("100 similarity pairs\n")
    similar_pairs = similar_pairs.filter("datasetA.userId < datasetB.userId").orderBy("JaccardDistance", ascending=True).limit(100)
    # top_100_pairs.select("datasetA.userId", "datasetB.userId", "JaccardDistance").show(100)
    # top_100_pairs.printSchema()

    print("Simplified df\n")
    simplified_df = similar_pairs.select(
        col("datasetA.userId").alias("userIdA"),
        col("datasetB.userId").alias("userIdB"),
        "JaccardDistance"
    )

    print("Write simplified df to CSV\n")
    # Write the simplified DataFrame to parquet
    simplified_df.write.parquet('top100pairs_all')

# %%
# Only enter this block if we're in main
if __name__ == "__main__":

    # Create the spark session object
#     spark = SparkSession.builder.appName('minHash').getOrCreate()

    spark = SparkSession.builder \
                        .appName('minHash') \
                        .getOrCreate()

    # Call our main routine
    main(spark)
# Out:
# 24/05/10 11:00:42 WARN CacheManager: Asked to cache already cached data.
# 24/05/10 11:00:42 WARN MemoryStore: Not enough space to cache rdd_7_5 in memory! (computed 2.8 MiB so far)
# 24/05/10 11:00:45 WARN MemoryStore: Not enough space to cache rdd_7_73 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:00:45 WARN MemoryStore: Not enough space to cache rdd_7_74 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:00:45 WARN MemoryStore: Not enough space to cache rdd_7_75 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:45 WARN MemoryStore: Not enough space to cache rdd_7_76 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:00:45 WARN MemoryStore: Not enough space to cache rdd_7_77 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:00:45 WARN MemoryStore: Not enough space to cache rdd_7_78 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:00:45 WARN MemoryStore: Not enough space to cache rdd_7_79 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_80 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_81 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_82 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_83 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_84 in memory! (computed 2.8 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_85 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_86 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_87 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_88 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_89 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_90 in memory! (computed 2.4 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_91 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_92 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_93 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_94 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_95 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_96 in memory! (computed 2.8 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_97 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:00:46 WARN MemoryStore: Not enough space to cache rdd_7_98 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:00:47 WARN MemoryStore: Not enough space to cache rdd_7_99 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:00:47 WARN MemoryStore: Not enough space to cache rdd_7_100 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:00:47 WARN MemoryStore: Not enough space to cache rdd_7_101 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:47 WARN MemoryStore: Not enough space to cache rdd_7_102 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:00:47 WARN MemoryStore: Not enough space to cache rdd_7_103 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:47 WARN MemoryStore: Not enough space to cache rdd_7_104 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:00:47 WARN MemoryStore: Not enough space to cache rdd_7_105 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:00:47 WARN MemoryStore: Not enough space to cache rdd_7_106 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:00:47 WARN MemoryStore: Not enough space to cache rdd_7_107 in memory! (computed 3.0 MiB so far)
# Transformed Data
#
# 100 similarity pairs
#
# Simplified df
#
# Write simplified df to CSV
# 24/05/10 11:00:57 WARN MemoryStore: Not enough space to cache rdd_7_10 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:08 WARN MemoryStore: Not enough space to cache rdd_7_73 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:01:08 WARN MemoryStore: Not enough space to cache rdd_7_74 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:01:09 WARN MemoryStore: Not enough space to cache rdd_7_75 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:09 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_76 in memory.
# 24/05/10 11:01:09 WARN MemoryStore: Not enough space to cache rdd_7_76 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:09 WARN MemoryStore: Not enough space to cache rdd_7_77 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:09 WARN MemoryStore: Not enough space to cache rdd_7_78 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:01:10 WARN MemoryStore: Not enough space to cache rdd_7_79 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_80 in memory.
# 24/05/10 11:01:10 WARN MemoryStore: Not enough space to cache rdd_7_80 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:10 WARN MemoryStore: Not enough space to cache rdd_7_81 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:10 WARN MemoryStore: Not enough space to cache rdd_7_82 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:10 WARN MemoryStore: Not enough space to cache rdd_7_83 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:10 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_84 in memory.
# 24/05/10 11:01:10 WARN MemoryStore: Not enough space to cache rdd_7_84 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:11 WARN MemoryStore: Not enough space to cache rdd_7_85 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:11 WARN MemoryStore: Not enough space to cache rdd_7_86 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:11 WARN MemoryStore: Not enough space to cache rdd_7_87 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:11 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_88 in memory.
# 24/05/10 11:01:11 WARN MemoryStore: Not enough space to cache rdd_7_88 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:12 WARN MemoryStore: Not enough space to cache rdd_7_89 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:12 WARN MemoryStore: Not enough space to cache rdd_7_90 in memory! (computed 2.4 MiB so far)
# 24/05/10 11:01:12 WARN MemoryStore: Not enough space to cache rdd_7_91 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_92 in memory.
# 24/05/10 11:01:12 WARN MemoryStore: Not enough space to cache rdd_7_92 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:12 WARN MemoryStore: Not enough space to cache rdd_7_93 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:01:13 WARN MemoryStore: Not enough space to cache rdd_7_94 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:13 WARN MemoryStore: Not enough space to cache rdd_7_95 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:13 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_96 in memory.
# 24/05/10 11:01:13 WARN MemoryStore: Not enough space to cache rdd_7_96 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:13 WARN MemoryStore: Not enough space to cache rdd_7_97 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:01:13 WARN MemoryStore: Not enough space to cache rdd_7_98 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:13 WARN MemoryStore: Not enough space to cache rdd_7_99 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:01:14 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_100 in memory.
# 24/05/10 11:01:14 WARN MemoryStore: Not enough space to cache rdd_7_100 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:14 WARN MemoryStore: Not enough space to cache rdd_7_101 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:14 WARN MemoryStore: Not enough space to cache rdd_7_102 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:14 WARN MemoryStore: Not enough space to cache rdd_7_103 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:15 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_104 in memory.
# 24/05/10 11:01:15 WARN MemoryStore: Not enough space to cache rdd_7_104 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:15 WARN MemoryStore: Not enough space to cache rdd_7_105 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:01:15 WARN MemoryStore: Not enough space to cache rdd_7_106 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:01:15 WARN MemoryStore: Not enough space to cache rdd_7_107 in memory! (computed 3.0 MiB so far)
# 24/05/10 11:01:35 WARN MemoryStore: Not enough space to cache rdd_7_10 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:47 WARN MemoryStore: Not enough space to cache rdd_7_73 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:01:47 WARN MemoryStore: Not enough space to cache rdd_7_74 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:01:47 WARN MemoryStore: Not enough space to cache rdd_7_75 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:47 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_76 in memory.
# 24/05/10 11:01:47 WARN MemoryStore: Not enough space to cache rdd_7_76 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:48 WARN MemoryStore: Not enough space to cache rdd_7_77 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:48 WARN MemoryStore: Not enough space to cache rdd_7_78 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:01:48 WARN MemoryStore: Not enough space to cache rdd_7_79 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_80 in memory.
# 24/05/10 11:01:48 WARN MemoryStore: Not enough space to cache rdd_7_80 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:48 WARN MemoryStore: Not enough space to cache rdd_7_81 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:48 WARN MemoryStore: Not enough space to cache rdd_7_82 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:49 WARN MemoryStore: Not enough space to cache rdd_7_83 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:49 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_84 in memory.
# 24/05/10 11:01:49 WARN MemoryStore: Not enough space to cache rdd_7_84 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:49 WARN MemoryStore: Not enough space to cache rdd_7_85 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:49 WARN MemoryStore: Not enough space to cache rdd_7_86 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:49 WARN MemoryStore: Not enough space to cache rdd_7_87 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_88 in memory.
# 24/05/10 11:01:50 WARN MemoryStore: Not enough space to cache rdd_7_88 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:50 WARN MemoryStore: Not enough space to cache rdd_7_89 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:50 WARN MemoryStore: Not enough space to cache rdd_7_91 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:50 WARN MemoryStore: Not enough space to cache rdd_7_90 in memory! (computed 2.4 MiB so far)
# 24/05/10 11:01:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_92 in memory.
# 24/05/10 11:01:50 WARN MemoryStore: Not enough space to cache rdd_7_92 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:51 WARN MemoryStore: Not enough space to cache rdd_7_93 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:01:51 WARN MemoryStore: Not enough space to cache rdd_7_94 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:51 WARN MemoryStore: Not enough space to cache rdd_7_95 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:51 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_96 in memory.
# 24/05/10 11:01:51 WARN MemoryStore: Not enough space to cache rdd_7_96 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:52 WARN MemoryStore: Not enough space to cache rdd_7_97 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:01:52 WARN MemoryStore: Not enough space to cache rdd_7_98 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:52 WARN MemoryStore: Not enough space to cache rdd_7_99 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:01:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_100 in memory.
# 24/05/10 11:01:52 WARN MemoryStore: Not enough space to cache rdd_7_100 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:52 WARN MemoryStore: Not enough space to cache rdd_7_101 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:52 WARN MemoryStore: Not enough space to cache rdd_7_102 in memory! (computed 2.6 MiB so far)
# 24/05/10 11:01:53 WARN MemoryStore: Not enough space to cache rdd_7_103 in memory! (computed 2.7 MiB so far)
# 24/05/10 11:01:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_7_104 in memory.
# 24/05/10 11:01:53 WARN MemoryStore: Not enough space to cache rdd_7_104 in memory! (computed 384.0 B so far)
# 24/05/10 11:01:53 WARN MemoryStore: Not enough space to cache rdd_7_105 in memory! (computed 2.5 MiB so far)
# 24/05/10 11:01:53 WARN MemoryStore: Not enough space to cache rdd_7_106 in memory! (computed 2.9 MiB so far)
# 24/05/10 11:01:53 WARN MemoryStore: Not enough space to cache rdd_7_107 in memory! (computed 3.0 MiB so far)

# %%
'''
+--------------------+--------------------+------------------+
|            datasetA|            datasetB|   JaccardDistance|
+--------------------+--------------------+------------------+
|{159361, [50, 318...|{6820, [318, 4995...|0.5555555555555556|
|{112094, [1196, 1...|{112094, [1196, 1...|               0.0|
|{254602, [48, 150...|{254602, [48, 150...|               0.0|
|{257335, [260, 31...|{257335, [260, 31...|               0.0|
|{288760, [1, 47, ...|{288760, [1, 47, ...|               0.0|
|{214820, [2028, 2...|{214820, [2028, 2...|               0.0|
|{77749, [223, 296...|{77749, [223, 296...|               0.0|
|{26650, [318, 527...|{85346, [260, 527...|0.5151515151515151|
|{131756, [3578, 3...|{214189, [260, 52...|0.5227272727272727|
|{185669, [318, 35...|{185669, [318, 35...|               0.0|
|{278829, [10, 18,...|{278829, [10, 18,...|               0.0|
|{220550, [260, 29...|{220550, [260, 29...|               0.0|
|{137155, [19, 165...|{137155, [19, 165...|               0.0|
|{93424, [260, 356...|{93424, [260, 356...|               0.0|
|{131505, [260, 29...|{131505, [260, 29...|               0.0|
|{271048, [6, 50, ...|{271048, [6, 50, ...|               0.0|
|{200191, [47, 185...|{200191, [47, 185...|               0.0|
|{10131, [44, 70, ...|{10131, [44, 70, ...|               0.0|
|{276465, [277, 34...|{276465, [277, 34...|               0.0|
|{98347, [2302], (...|{319979, [1639, 2...|               0.5|
+--------------------+--------------------+------------------+
only showing top 20 rows
'''

# %%
from pyspark.sql import SparkSession

# Create a Spark session
spark = SparkSession.builder \
    .appName("Read and Process Parquet Files") \
    .getOrCreate()

# Read Parquet files from a specified path or multiple paths
df = spark.read.parquet("top100pairs_all")


# Order by a specific column and limit to 100 records
result_df = df.orderBy("JaccardDistance", ascending=True).limit(100)

# Show the results
result_df.write.csv('q1_results', header=True)

# Stop the Spark session
spark.stop()
